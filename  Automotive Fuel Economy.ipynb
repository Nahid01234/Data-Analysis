# %% [markdown]
#                                          Automotive Fuel Economy
#                                    --------------------------------
# This dataset contains the fuel economy in miles per gallon (mpg) for 398 cars sold in the US in the 1970s and 1980s. The data includes vehicle characteristics including horsepower, acceleration, country of origin, and more.
#
# Recommended Analysis:
#
# 1.What is the overall trend in fuel economy over time?
#
# 2.Which automobile characteristic is most correlated to fuel economy?
#
# 3.Is there a difference in fuel economy by the origin of the car produced? If so, is there an underlying difference in the types of cars manufactured in   each?
#
#
# -------------------------------------------------------------------------------------------------------------
# mpg                      :The fuel economy of the car in terms of miles travelled per gallon of gasoline,,,,
# cylinders                :The number of cylinders in the car's engine,,,,
# displacement             :The volume of air displaced by all the pistons of a piston engine,,,,
# horsepower               :Horsepower is a measure of power the engine produces,,,,
# weight                   :The total weight of the car,,,,
# acceleration             :The time in seconds it takes for the car to reach 60 miles per hour,,,,
# model year               :The year (in the 20th century) the car model was released. For example 80 means the car was released in 1980.,,,,
# origin                   :The region where the car was manufactured. 1 - USA. 2 - Europe. 3 - Japan,,,,
# car name                 :The name of the car model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("auto-mpg.csv")

# %%
df.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# # Question-1
# ###  Answer:
# 1970–1982: During this period, there was a rapid increase in average fuel economy.

# %%
df["mpg"].mean()
# Out:
# 23.514572864321615

# %%
df["mpg"].median()
# Out:
# 23.0

# %%
df["mpg"].plot.box()
# Out:
# <AxesSubplot:>

# %%
model_car=df.groupby(df["model year"])["mpg"].mean()

# %%
model_car
# Out:
# model year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
model_car=pd.DataFrame(model_car)

# %%
(model_car)
# Out:
#                   mpg
# model year
# 70          17.689655
# 71          21.250000
# 72          18.714286
# 73          17.100000
# 74          22.703704
# 75          20.266667
# 76          21.573529
# 77          23.375000
# 78          24.061111
# 79          25.093103
# 80          33.696552
# 81          30.334483
# 82          31.709677

# %%
(model_car).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='model year'>

# %%
plt.pie(model_car["mpg"],labels=model_car.index,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# # Question-2
# ### Answer:
#   "model year" is the most correlated to fuel economy

# %%
df1=df[["mpg","cylinders","displacement","horsepower","weight","acceleration","origin","model year"]]

# %%
df1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  origin  \
# 0    18.0          8         307.0        130    3504          12.0     USA
# 1    15.0          8         350.0        165    3693          11.5     USA
# 2    18.0          8         318.0        150    3436          11.0     USA
# 3    16.0          8         304.0        150    3433          12.0     USA
# 4    17.0          8         302.0        140    3449          10.5     USA
# ..    ...        ...           ...        ...     ...           ...     ...
# 393  27.0          4         140.0         86    2790          15.6     USA
# 394  44.0          4          97.0         52    2130          24.6  EUROPE
# 395  32.0          4         135.0         84    2295          11.6     USA
# 396  28.0          4         120.0         79    2625          18.6     USA
# 397  31.0          4         119.0         82    2720          19.4     USA
#
#      model year
# 0          1970
# 1          1970
# ...

# %%
df1.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
#
#               model year
# mpg             0.579267
# cylinders      -0.348746
# displacement   -0.370164
# weight         -0.306564
# acceleration    0.288137
# model year      1.000000

# %%
plt.figure(figsize=(4,4))
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Question-3
# ### Answer:
#  There is a difference in fuel economy by the origin of the car produced.The Average fuel economy is higher in JAPAN than EUROPE & USA.There is there an underlying difference in the types of cars manufactured in each.They are different in each origin with their characteristics..

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df["origin"].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
df["model year"]=df["model year"].replace([70,   71,   72,   73,   74,   75,   76,   77,   78,   79,   80,
         81, 82],[1970,   1971,   1972,   1973,   1974,   1975,   1976,   1977,   1978,   1979,   1980,
         1981, 1982])

# %%
df["origin"]=df["origin"].replace([1,2,3],["USA","EUROPE","JAPAN"])

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0          1970     USA  chevrolet chevelle malibu
# ...

# %%
df["model year"].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982], dtype=int64)

# %%
model_car=df.groupby(df1["origin"])["mpg"].mean()

# %%
model_car
# Out:
# origin
# EUROPE    27.891429
# JAPAN     30.450633
# USA       20.083534
# Name: mpg, dtype: float64

# %%
model_car.plot(kind="pie",autopct="%0.1f%%")
plt.show()

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0          1970     USA  chevrolet chevelle malibu
# ...

# %%
df_japan=df[df["origin"]=="JAPAN"]

# %%
df_japan
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 14   24.0          4         113.0         95    2372          15.0
# 18   27.0          4          97.0         88    2130          14.5
# 29   27.0          4          97.0         88    2130          14.5
# 31   25.0          4         113.0         95    2228          14.0
# 53   31.0          4          71.0         65    1773          19.0
# ..    ...        ...           ...        ...     ...           ...
# 382  34.0          4         108.0         70    2245          16.9
# 383  38.0          4          91.0         67    1965          15.0
# 384  32.0          4          91.0         67    1965          15.7
# 385  38.0          4          91.0         67    1995          16.2
# 390  32.0          4         144.0         96    2665          13.9
#
#      model year origin               car name
# 14         1970  JAPAN  toyota corona mark ii
# 18         1970  JAPAN           datsun pl510
# ...

# %%
df_japan.set_index(np.arange(79),inplace=True)

# %%
df_japan
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   24.0          4         113.0         95    2372          15.0
# 1   27.0          4          97.0         88    2130          14.5
# 2   27.0          4          97.0         88    2130          14.5
# 3   25.0          4         113.0         95    2228          14.0
# 4   31.0          4          71.0         65    1773          19.0
# ..   ...        ...           ...        ...     ...           ...
# 74  34.0          4         108.0         70    2245          16.9
# 75  38.0          4          91.0         67    1965          15.0
# 76  32.0          4          91.0         67    1965          15.7
# 77  38.0          4          91.0         67    1995          16.2
# 78  32.0          4         144.0         96    2665          13.9
#
#     model year origin               car name
# 0         1970  JAPAN  toyota corona mark ii
# 1         1970  JAPAN           datsun pl510
# ...

# %%
df_jp=df_japan["car name"].str.split(" ")
list(df_jp)
# Out:
# [['toyota', 'corona', 'mark', 'ii'],
#  ['datsun', 'pl510'],
#  ['datsun', 'pl510'],
#  ['toyota', 'corona'],
#  ['toyota', 'corolla', '1200'],
#  ['datsun', '1200'],
#  ['toyota', 'corona', 'hardtop'],
#  ['mazda', 'rx2', 'coupe'],
#  ['datsun', '510', '(sw)'],
#  ['toyouta', 'corona', 'mark', 'ii', '(sw)'],
#  ['toyota', 'corolla', '1600', '(sw)'],
#  ['toyota', 'carina'],
#  ['datsun', '610'],
#  ['maxda', 'rx3'],
#  ['toyota', 'mark', 'ii'],
#  ['datsun', 'b210'],
#  ['toyota', 'corolla', '1200'],
#  ['toyota', 'corona'],
#  ['datsun', '710'],
#  ['honda', 'civic'],
#  ['subaru'],
#  ['toyota', 'corolla'],
#  ['toyota', 'corona'],
#  ['datsun', '710'],
#  ['honda', 'civic', 'cvcc'],
#  ['honda', 'civic'],
#  ['datsun', 'b-210'],
#  ['toyota', 'corolla'],
#  ['toyota', 'mark', 'ii'],
#  ['honda', 'accord', 'cvcc'],
#  ['datsun', 'f-10', 'hatchback'],
#  ['toyota', 'corolla', 'liftback'],
#  ['subaru', 'dl'],
#  ['datsun', '810'],
#  ['mazda', 'rx-4'],
# ...

# %%
jp=[]
for i in list(df_jp):
    jp.append(i[0])
jp    
print(len(jp))
# Out:
# 79

# %%
japan=pd.DataFrame(jp)

# %%
japan.columns=["CAR_name"]

# %%
japan
# Out:
#    CAR_name
# 0    toyota
# 1    datsun
# 2    datsun
# 3    toyota
# 4    toyota
# ..      ...
# 74   toyota
# 75    honda
# 76    honda
# 77   datsun
# 78   toyota
#
# [79 rows x 1 columns]

# %%
df_japan=pd.concat([df_japan,japan],axis=1)

# %%
df_japan
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   24.0          4         113.0         95    2372          15.0
# 1   27.0          4          97.0         88    2130          14.5
# 2   27.0          4          97.0         88    2130          14.5
# 3   25.0          4         113.0         95    2228          14.0
# 4   31.0          4          71.0         65    1773          19.0
# ..   ...        ...           ...        ...     ...           ...
# 74  34.0          4         108.0         70    2245          16.9
# 75  38.0          4          91.0         67    1965          15.0
# 76  32.0          4          91.0         67    1965          15.7
# 77  38.0          4          91.0         67    1995          16.2
# 78  32.0          4         144.0         96    2665          13.9
#
#     model year origin               car name CAR_name
# 0         1970  JAPAN  toyota corona mark ii   toyota
# ...

# %%
df_japan.drop(columns="car name",axis=1,inplace=True)

# %%
df_japan
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   24.0          4         113.0         95    2372          15.0
# 1   27.0          4          97.0         88    2130          14.5
# 2   27.0          4          97.0         88    2130          14.5
# 3   25.0          4         113.0         95    2228          14.0
# 4   31.0          4          71.0         65    1773          19.0
# ..   ...        ...           ...        ...     ...           ...
# 74  34.0          4         108.0         70    2245          16.9
# 75  38.0          4          91.0         67    1965          15.0
# 76  32.0          4          91.0         67    1965          15.7
# 77  38.0          4          91.0         67    1995          16.2
# 78  32.0          4         144.0         96    2665          13.9
#
#     model year origin CAR_name
# 0         1970  JAPAN   toyota
# 1         1970  JAPAN   datsun
# 2         1971  JAPAN   datsun
# 3         1971  JAPAN   toyota
# ...

# %%
df_japan["CAR_name"].unique()
# Out:
# array(['toyota', 'datsun', 'mazda', 'toyouta', 'maxda', 'honda', 'subaru',
#        'nissan'], dtype=object)

# %%
df_japan["CAR_name"]=df_japan["CAR_name"].replace(['toyouta','maxda'],['toyota','mazda'])

# %%
df_japan["CAR_name"].unique()
# Out:
# array(['toyota', 'datsun', 'mazda', 'honda', 'subaru', 'nissan'],
#       dtype=object)

# %%
df_japan["CAR_name"].value_counts()
# Out:
# toyota    26
# datsun    23
# honda     13
# mazda     12
# subaru     4
# nissan     1
# Name: CAR_name, dtype: int64

# %%
sns.countplot(data=df_japan,x="CAR_name")
plt.xlabel("Name of Car")
plt.ylabel("Number of Car")
plt.show()

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df["origin"]=df["origin"].replace([1,2,3],["USA","EUROPE","JAPAN"])

# %%
df_europe=df[df["origin"]=="EUROPE"]

# %%
df_europe
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 19   26.0          4          97.0         46    1835          20.5
# 20   25.0          4         110.0         87    2672          17.5
# 21   24.0          4         107.0         90    2430          14.5
# 22   25.0          4         104.0         95    2375          17.5
# 23   26.0          4         121.0        113    2234          12.5
# ..    ...        ...           ...        ...     ...           ...
# 354  34.5          4         100.0          ?    2320          15.8
# 359  28.1          4         141.0         80    3230          20.4
# 360  30.7          6         145.0         76    3160          19.6
# 375  36.0          4         105.0         74    1980          15.3
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                      car name
# 19           70  EUROPE  volkswagen 1131 deluxe sedan
# ...

# %%
df_europe.set_index(np.arange(70),inplace=True)

# %%
df_europe
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   26.0          4          97.0         46    1835          20.5
# 1   25.0          4         110.0         87    2672          17.5
# 2   24.0          4         107.0         90    2430          14.5
# 3   25.0          4         104.0         95    2375          17.5
# 4   26.0          4         121.0        113    2234          12.5
# ..   ...        ...           ...        ...     ...           ...
# 65  34.5          4         100.0          ?    2320          15.8
# 66  28.1          4         141.0         80    3230          20.4
# 67  30.7          6         145.0         76    3160          19.6
# 68  36.0          4         105.0         74    1980          15.3
# 69  44.0          4          97.0         52    2130          24.6
#
#     model year  origin                      car name
# 0           70  EUROPE  volkswagen 1131 deluxe sedan
# 1           70  EUROPE                   peugeot 504
# ...

# %%
df_eu=df_europe["car name"].str.split(" ")
list(df_eu)
# Out:
# [['volkswagen', '1131', 'deluxe', 'sedan'],
#  ['peugeot', '504'],
#  ['audi', '100', 'ls'],
#  ['saab', '99e'],
#  ['bmw', '2002'],
#  ['opel', '1900'],
#  ['peugeot', '304'],
#  ['fiat', '124b'],
#  ['volkswagen', 'model', '111'],
#  ['volkswagen', 'type', '3'],
#  ['volvo', '145e', '(sw)'],
#  ['volkswagen', '411', '(sw)'],
#  ['peugeot', '504', '(sw)'],
#  ['renault', '12', '(sw)'],
#  ['volkswagen', 'super', 'beetle'],
#  ['fiat', '124', 'sport', 'coupe'],
#  ['fiat', '128'],
#  ['opel', 'manta'],
#  ['audi', '100ls'],
#  ['volvo', '144ea'],
#  ['saab', '99le'],
#  ['audi', 'fox'],
#  ['volkswagen', 'dasher'],
#  ['opel', 'manta'],
#  ['fiat', '128'],
#  ['fiat', '124', 'tc'],
#  ['fiat', 'x1.9'],
#  ['volkswagen', 'dasher'],
#  ['volkswagen', 'rabbit'],
#  ['audi', '100ls'],
#  ['peugeot', '504'],
#  ['volvo', '244dl'],
#  ['saab', '99le'],
#  ['fiat', '131'],
#  ['opel', '1900'],
#  ['renault', '12tl'],
#  ['vw', 'rabbit'],
#  ['volkswagen', 'rabbit'],
#  ['volvo', '245'],
# ...

# %%
eu=[]
for i in list(df_eu):
    eu.append(i[0])
eu    
print(len(eu))
# Out:
# 70

# %%
europe=pd.DataFrame(eu)

# %%
europe.columns=["CAR_NAME"]

# %%
europe
# Out:
#       CAR_NAME
# 0   volkswagen
# 1      peugeot
# 2         audi
# 3         saab
# 4          bmw
# ..         ...
# 65     renault
# 66     peugeot
# 67       volvo
# 68  volkswagen
# 69          vw
#
# [70 rows x 1 columns]

# %%
df_europe=pd.concat([df_europe,europe],axis=1)

# %%
df_europe
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   26.0          4          97.0         46    1835          20.5
# 1   25.0          4         110.0         87    2672          17.5
# 2   24.0          4         107.0         90    2430          14.5
# 3   25.0          4         104.0         95    2375          17.5
# 4   26.0          4         121.0        113    2234          12.5
# ..   ...        ...           ...        ...     ...           ...
# 65  34.5          4         100.0          ?    2320          15.8
# 66  28.1          4         141.0         80    3230          20.4
# 67  30.7          6         145.0         76    3160          19.6
# 68  36.0          4         105.0         74    1980          15.3
# 69  44.0          4          97.0         52    2130          24.6
#
#     model year  origin                      car name    CAR_NAME
# 0           70  EUROPE  volkswagen 1131 deluxe sedan  volkswagen
# ...

# %%
df_europe.drop(columns="car name",axis=1,inplace=True)

# %%
df_europe
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   26.0          4          97.0         46    1835          20.5
# 1   25.0          4         110.0         87    2672          17.5
# 2   24.0          4         107.0         90    2430          14.5
# 3   25.0          4         104.0         95    2375          17.5
# 4   26.0          4         121.0        113    2234          12.5
# ..   ...        ...           ...        ...     ...           ...
# 65  34.5          4         100.0          ?    2320          15.8
# 66  28.1          4         141.0         80    3230          20.4
# 67  30.7          6         145.0         76    3160          19.6
# 68  36.0          4         105.0         74    1980          15.3
# 69  44.0          4          97.0         52    2130          24.6
#
#     model year  origin    CAR_NAME
# 0           70  EUROPE  volkswagen
# 1           70  EUROPE     peugeot
# 2           70  EUROPE        audi
# ...

# %%
df_europe["CAR_NAME"].unique()
# Out:
# array(['volkswagen', 'peugeot', 'audi', 'saab', 'bmw', 'opel', 'fiat',
#        'volvo', 'renault', 'vw', 'mercedes-benz', 'mercedes', 'vokswagen',
#        'triumph'], dtype=object)

# %%
df_europe["CAR_NAME"]=df_europe["CAR_NAME"].replace(['vokswagen',"vw"],'volkswagen')

# %%
df_europe["CAR_NAME"].unique()
# Out:
# array(['volkswagen', 'peugeot', 'audi', 'saab', 'bmw', 'opel', 'fiat',
#        'volvo', 'renault', 'mercedes-benz', 'mercedes', 'triumph'],
#       dtype=object)

# %%
df_europe["CAR_NAME"]=df_europe["CAR_NAME"].replace('mercedes-benz', 'mercedes')

# %%
df_europe["CAR_NAME"].unique()
# Out:
# array(['volkswagen', 'peugeot', 'audi', 'saab', 'bmw', 'opel', 'fiat',
#        'volvo', 'renault', 'mercedes', 'triumph'], dtype=object)

# %%
df_europe["CAR_NAME"].value_counts()
# Out:
# volkswagen    22
# peugeot        8
# fiat           8
# audi           7
# volvo          6
# renault        5
# saab           4
# opel           4
# mercedes       3
# bmw            2
# triumph        1
# Name: CAR_NAME, dtype: int64

# %%
sns.countplot(data=df_europe,x="CAR_NAME")
plt.xlabel("Name of Car")
plt.ylabel("Number of Car")
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70     USA  chevrolet chevelle malibu
# ...

# %%
df_usa=df[df["origin"]=="USA"]

# %%
df_usa
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year origin                   car name
# 0            70    USA  chevrolet chevelle malibu
# ...

# %%
df_usa.set_index(np.arange(249),inplace=True)

# %%
df_usa
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 244  27.0          4         151.0         90    2950          17.3
# 245  27.0          4         140.0         86    2790          15.6
# 246  32.0          4         135.0         84    2295          11.6
# 247  28.0          4         120.0         79    2625          18.6
# 248  31.0          4         119.0         82    2720          19.4
#
#      model year origin                   car name
# 0            70    USA  chevrolet chevelle malibu
# ...

# %%
df_us=df_usa["car name"].str.split(" ")
list(df_us)
# Out:
# [['chevrolet', 'chevelle', 'malibu'],
#  ['buick', 'skylark', '320'],
#  ['plymouth', 'satellite'],
#  ['amc', 'rebel', 'sst'],
#  ['ford', 'torino'],
#  ['ford', 'galaxie', '500'],
#  ['chevrolet', 'impala'],
#  ['plymouth', 'fury', 'iii'],
#  ['pontiac', 'catalina'],
#  ['amc', 'ambassador', 'dpl'],
#  ['dodge', 'challenger', 'se'],
#  ['plymouth', "'cuda", '340'],
#  ['chevrolet', 'monte', 'carlo'],
#  ['buick', 'estate', 'wagon', '(sw)'],
#  ['plymouth', 'duster'],
#  ['amc', 'hornet'],
#  ['ford', 'maverick'],
#  ['amc', 'gremlin'],
#  ['ford', 'f250'],
#  ['chevy', 'c20'],
#  ['dodge', 'd200'],
#  ['hi', '1200d'],
#  ['chevrolet', 'vega', '2300'],
#  ['ford', 'pinto'],
#  ['amc', 'gremlin'],
#  ['plymouth', 'satellite', 'custom'],
#  ['chevrolet', 'chevelle', 'malibu'],
#  ['ford', 'torino', '500'],
#  ['amc', 'matador'],
#  ['chevrolet', 'impala'],
#  ['pontiac', 'catalina', 'brougham'],
#  ['ford', 'galaxie', '500'],
#  ['plymouth', 'fury', 'iii'],
# ...

# %%
us=[]
for i in list(df_us):
    us.append(i[0])
us    
print(len(us))
# Out:
# 249

# %%
usa=pd.DataFrame(us)

# %%
usa.columns=["CAR_NAME"]

# %%
usa
# Out:
#       CAR_NAME
# 0    chevrolet
# 1        buick
# 2     plymouth
# 3          amc
# 4         ford
# ..         ...
# 244  chevrolet
# 245       ford
# 246      dodge
# 247       ford
# 248      chevy
#
# [249 rows x 1 columns]

# %%
df_usa=pd.concat([df_usa,usa],axis=1)

# %%
df_usa
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 244  27.0          4         151.0         90    2950          17.3
# 245  27.0          4         140.0         86    2790          15.6
# 246  32.0          4         135.0         84    2295          11.6
# 247  28.0          4         120.0         79    2625          18.6
# 248  31.0          4         119.0         82    2720          19.4
#
#      model year origin                   car name   CAR_NAME
# 0            70    USA  chevrolet chevelle malibu  chevrolet
# ...

# %%
df_usa.drop(columns="car name",axis=1,inplace=True)

# %%
df_usa
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 244  27.0          4         151.0         90    2950          17.3
# 245  27.0          4         140.0         86    2790          15.6
# 246  32.0          4         135.0         84    2295          11.6
# 247  28.0          4         120.0         79    2625          18.6
# 248  31.0          4         119.0         82    2720          19.4
#
#      model year origin   CAR_NAME
# 0            70    USA  chevrolet
# 1            70    USA      buick
# 2            70    USA   plymouth
# ...

# %%
df_usa["CAR_NAME"].unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'chevy', 'hi', 'mercury', 'oldsmobile', 'chrysler',
#        'chevroelt', 'capri', 'cadillac'], dtype=object)

# %%
df_usa["CAR_NAME"]=df_usa["CAR_NAME"].replace(['chevroelt','chevy'],'chevrolet')

# %%
df_usa["CAR_NAME"].unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'hi', 'mercury', 'oldsmobile', 'chrysler', 'capri',
#        'cadillac'], dtype=object)

# %%
df_usa["CAR_NAME"]=df_usa["CAR_NAME"].replace('capri','ford')

# %%
df_usa["CAR_NAME"].unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'hi', 'mercury', 'oldsmobile', 'chrysler', 'cadillac'],
#       dtype=object)

# %%
df_usa[df_usa["CAR_NAME"]=="hi"]
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 21  9.0          8         304.0        193    4732          18.5          70
#
#    origin CAR_NAME
# 21    USA       hi

# %%
df_usa=df_usa.drop(df_usa[df_usa['CAR_NAME'] == 'hi'].index)

# %%
df_usa["CAR_NAME"].unique()
# Out:
# array(['chevrolet', 'buick', 'plymouth', 'amc', 'ford', 'pontiac',
#        'dodge', 'mercury', 'oldsmobile', 'chrysler', 'cadillac'],
#       dtype=object)

# %%
df_usa["CAR_NAME"].value_counts()
# Out:
# ford          52
# chevrolet     47
# plymouth      31
# amc           28
# dodge         28
# buick         17
# pontiac       16
# mercury       11
# oldsmobile    10
# chrysler       6
# cadillac       2
# Name: CAR_NAME, dtype: int64

# %%
sns.countplot(data=df_usa,x="CAR_NAME")
plt.xlabel("Name of Car")
plt.ylabel("Number of Car")
plt.xticks(rotation='vertical')
plt.show()
